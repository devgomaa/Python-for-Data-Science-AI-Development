# %%
#importing libraries
import pandas as pd
import dabl

# %%
#reading the dataset
data = pd.read_csv('diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
data_clean = dabl.clean(data, target_col='Outcome', verbose=1)
data_clean.head()
# Out:
# Detected feature types:
# 2 float, 7 int, 0 object, 0 date, 0 other
# Interpreted as:
# continuous      7
# dirty_float     0
# low_card_int    1
# categorical     1
# date            0
# free_string     0
# useless         0
# dtype: int64
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age Outcome
# 0                     0.127   47       1
# 1                     0.233   23       0
# 2                     0.630   31       1
# 3                     0.365   24       1
# 4                     0.536   21       0

# %%
types = dabl.detect_types(data_clean)
types
# Out:
#                           continuous  dirty_float  low_card_int  categorical  \
# Pregnancies                    False        False          True        False
# Glucose                         True        False         False        False
# BloodPressure                   True        False         False        False
# SkinThickness                   True        False         False        False
# Insulin                         True        False         False        False
# BMI                             True        False         False        False
# DiabetesPedigreeFunction        True        False         False        False
# Age                             True        False         False        False
# Outcome                        False        False         False         True
#
#                            date  free_string  useless
# Pregnancies               False        False    False
# Glucose                   False        False    False
# BloodPressure             False        False    False
# SkinThickness             False        False    False
# Insulin                   False        False    False
# BMI                       False        False    False
# DiabetesPedigreeFunction  False        False    False
# Age                       False        False    False
# Outcome                   False        False    False

# %%
dabl.plot(data_clean, target_col='Outcome')
# Out:
# Target looks like classification
# c:\users\sys\appdata\local\programs\python\python36\lib\site-packages\dabl\plot\utils.py:630: UserWarning: Dropped 2 outliers in column BMI.
#   int(dropped), series.name), UserWarning)
# c:\users\sys\appdata\local\programs\python\python36\lib\site-packages\dabl\plot\utils.py:630: UserWarning: Dropped 3 outliers in column DiabetesPedigreeFunction.
#   int(dropped), series.name), UserWarning)
# c:\users\sys\appdata\local\programs\python\python36\lib\site-packages\dabl\plot\utils.py:630: UserWarning: Dropped 2 outliers in column Insulin.
#   int(dropped), series.name), UserWarning)
# c:\users\sys\appdata\local\programs\python\python36\lib\site-packages\dabl\plot\utils.py:630: UserWarning: Dropped 4 outliers in column SkinThickness.
#   int(dropped), series.name), UserWarning)
# Linear Discriminant Analysis training set score: 0.728
