# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading the dataset
data = pd.read_csv('employee.csv')
pd.set_option('max_columns', 35)
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
pd.crosstab(data['EducationField'], data['Department'])
# Out:
# Department        Human Resources  Research & Development  Sales
# EducationField
# Human Resources                27                       0      0
# Life Sciences                  16                     440    150
# Marketing                       0                       0    159
# Medical                        13                     363     88
# Other                           3                      64     15
# Technical Degree                4                      94     34

# %%
pd.crosstab(data['EducationField'], data['Department']).style.bar(color=['gold'])
# Out:
# <style  type="text/css" >
#     #T_e1f8d368_3875_11eb_9135_705a0f084df1row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 100.0%, transparent 100.0%);
#         }    #T_e1f8d368_3875_11eb_9135_705a0f084df1row0_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_e1f8d368_3875_11eb_9135_705a0f084df1row0_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_e1f8d368_3875_11eb_9135_705a0f084df1row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 59.3%, transparent 59.3%);
#         }    #T_e1f8d368_3875_11eb_9135_705a0f084df1row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 100.0%, transparent 100.0%);
#         }    #T_e1f8d368_3875_11eb_9135_705a0f084df1row1_col2 {
#             width:  10em;
# ...

# %%
data.groupby(['Department','JobRole'])[['MonthlyIncome',
                                        'MonthlyRate',
                                        'HourlyRate']].agg(['max',
                                                            'min',
                                                            'mean'])
# Out:
#                                                  MonthlyIncome         \
#                                                            max    min
# Department             JobRole
# Human Resources        Human Resources                   10725   1555
#                        Manager                           19717  14026
# Research & Development Healthcare Representative         13966   4000
#                        Laboratory Technician              7403   1102
#                        Manager                           19999  11244
#                        Manufacturing Director            13973   4011
#                        Research Director                 19973  11031
#                        Research Scientist                 9724   1009
# Sales                  Manager                           19847  11557
#                        Sales Executive                   13872   4001
#                        Sales Representative               6632   1052
#
# ...

# %%
data.groupby(['Department','JobRole'])[['MonthlyIncome',
                                        'MonthlyRate',
                                        'HourlyRate']].agg(['max',
                                                            'min',
                                                            'mean']).style.background_gradient(
    cmap='copper')
# Out:
# <style  type="text/css" >
#     #T_2b88525c_3876_11eb_baea_705a0f084df1row0_col0 {
#             background-color:  #603d27;
#             color:  #f1f1f1;
#         }    #T_2b88525c_3876_11eb_baea_705a0f084df1row0_col1 {
#             background-color:  #0c0805;
#             color:  #f1f1f1;
#         }    #T_2b88525c_3876_11eb_baea_705a0f084df1row0_col2 {
#             background-color:  #20140d;
#             color:  #f1f1f1;
#         }    #T_2b88525c_3876_11eb_baea_705a0f084df1row0_col3 {
#             background-color:  #ffb674;
#             color:  #000000;
#         }    #T_2b88525c_3876_11eb_baea_705a0f084df1row0_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_2b88525c_3876_11eb_baea_705a0f084df1row0_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_2b88525c_3876_11eb_baea_705a0f084df1row0_col6 {
#             background-color:  #ffc77f;
#             color:  #000000;
# ...
